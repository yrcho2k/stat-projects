# %%
import pandas as pd

# %%
Disaster = pd.read_csv("DisasterDeclarationsSummaries.csv")

# %%
Disaster.shape
Disaster.head()
# Out:
#   femaDeclarationString  disasterNumber state declarationType  \
# 0            FM-5464-RI            5464    RI              FM
# 1            FM-5463-KS            5463    KS              FM
# 2            DR-4731-CO            4731    CO              DR
# 3            DR-4731-CO            4731    CO              DR
# 4            DR-4731-CO            4731    CO              DR
#
#             declarationDate  fyDeclared incidentType  \
# 0  2023-04-14T00:00:00.000Z        2023         Fire
# 1  2023-04-13T00:00:00.000Z        2023         Fire
# 2  2023-08-25T00:00:00.000Z        2023        Flood
# 3  2023-08-25T00:00:00.000Z        2023        Flood
# 4  2023-08-25T00:00:00.000Z        2023        Flood
#
#                          declarationTitle  ihProgramDeclared  \
# 0                       QUEENS RIVER FIRE                  0
# 1                             HADDAM FIRE                  0
# 2  SEVERE STORMS, FLOODING, AND TORNADOES                  0
# 3  SEVERE STORMS, FLOODING, AND TORNADOES                  0
# 4  SEVERE STORMS, FLOODING, AND TORNADOES                  0
#
#    iaProgramDeclared  ...  tribalRequest  fipsStateCode fipsCountyCode  \
# 0                  0  ...              0             44              9
# 1                  0  ...              0             20            201
# 2                  0  ...              0              8              9
# 3                  0  ...              0              8             61
# 4                  0  ...              0              8             99
#
#   placeCode                            designatedArea  \
# 0     99009  Washington (County)(in (P)MSA 5520,6480)
# 1     99201                       Washington (County)
# 2     99009                             Baca (County)
# 3     99061                            Kiowa (County)
# 4     99099                          Prowers (County)
#
#    declarationRequestNumber  lastIAFilingDate               lastRefresh  \
# 0                     23042               NaN  2023-05-22T03:41:22.800Z
# 1                     23038               NaN  2023-05-22T03:41:22.800Z
# 2                     23081               NaN  2023-10-02T19:21:20.859Z
# 3                     23081               NaN  2023-10-02T19:21:20.859Z
# 4                     23081               NaN  2023-10-02T19:21:20.859Z
#
#                                        hash  \
# 0  1111d4d4a33f8a6e4d383ac5bd0e60b9bf142da0
# 1  78dd55a181f146622eb65835b5d794689d1ea7f2
# 2  44d903d3d79b5295f58aefdd35682a8d3011644d
# 3  ecfd4777766336e18a46d1eb231fc25922f8b014
# 4  90ab966409613986143ee242870748e8d19aa525
#
#                                      id
# 0  9b9a9d9c-8b03-4049-9b16-a3c0d581556c
# 1  57d936ce-a0d7-412a-9d78-18aee530c146
# 2  fe1befa2-d7ac-4400-b430-36bf30ac9a15
# 3  880f5941-94fb-4c00-afb8-2f1e32fe1b5b
# 4  875a66ca-6234-423a-9e92-3626484e11d6
#
# [5 rows x 25 columns]

# %%
COVID = Disaster[(Disaster['declarationTitle'] == 'COVID-19') | (Disaster['declarationTitle'] == 'COVID-19 PANDEMIC')].reset_index()

# %%
COVID['DeclarationDate'] = pd.to_datetime(COVID['declarationDate'].str[:10])

# %%
COVID.head()
# Out:
#    index femaDeclarationString  disasterNumber state declarationType  \
# 0    878            DR-4501-GA            4501    GA              DR
# 1    879            DR-4501-GA            4501    GA              DR
# 2    914            DR-4501-GA            4501    GA              DR
# 3   2215            DR-4591-AL            4591    AL              DR
# 4   2654            DR-4582-AZ            4582    AZ              DR
#
#             declarationDate  fyDeclared incidentType   declarationTitle  \
# 0  2020-03-29T00:00:00.000Z        2020   Biological  COVID-19 PANDEMIC
# 1  2020-03-29T00:00:00.000Z        2020   Biological  COVID-19 PANDEMIC
# 2  2020-03-29T00:00:00.000Z        2020   Biological  COVID-19 PANDEMIC
# 3  2021-03-28T00:00:00.000Z        2021   Biological  COVID-19 PANDEMIC
# 4  2021-02-02T00:00:00.000Z        2021   Biological  COVID-19 PANDEMIC
#
#    ihProgramDeclared  ...  fipsStateCode  fipsCountyCode  placeCode  \
# 0                  1  ...             13               1      99001
# 1                  1  ...             13               3      99003
# 2                  1  ...             13               5      99005
# 3                  1  ...              1               0      61430
# 4                  1  ...              4               0      48845
#
#                                designatedArea declarationRequestNumber  \
# 0                            Appling (County)                    20097
# 1                           Atkinson (County)                    20097
# 2                              Bacon (County)                    20097
# 3                Poarch Band of Creek Indians                    20185
# 4  Navajo Nation Reservation (Also NM and UT)                    21006
#
#            lastIAFilingDate               lastRefresh  \
# 0  2025-09-30T00:00:00.000Z  2023-06-26T16:01:24.896Z
# 1  2025-09-30T00:00:00.000Z  2023-06-26T16:01:24.896Z
# 2  2025-09-30T00:00:00.000Z  2023-06-26T16:01:24.896Z
# 3                       NaN  2023-05-22T03:41:22.800Z
# 4                       NaN  2023-05-22T03:41:22.800Z
#
#                                        hash  \
# 0  6ac38e1e9cb4e6ab6f70c5a39819ecfce72cfa40
# 1  439c437c81780ff98bb1df8becdab9e5fc0aec17
# 2  7281f26ae7ac371befae93deacf52c7b9a26fe4f
# 3  94f4b198b44b93b52f54f66964b65948482e8274
# 4  e4287f4f5da091d1e67efe30c4d933f05e4f89e0
#
#                                      id  DeclarationDate
# 0  fc92a7f7-82c9-4325-b5b6-40cc773c5a5a       2020-03-29
# 1  460f6fc9-5362-470d-942b-276ae8cffcfc       2020-03-29
# 2  536f5158-b7dc-4c22-8938-3029d0c89286       2020-03-29
# 3  ddd02c42-f592-40fa-8dd3-45a047fef44b       2021-03-28
# 4  860fac14-1b9b-47ac-8443-764b217db2e9       2021-02-02
#
# [5 rows x 27 columns]

# %%
N_declaration_by_date_and_state = COVID.groupby(['DeclarationDate', 'state']).agg(cases = ('index', 'count'))

# %%
N_declaration_by_date_and_state.to_csv("N_declaration_by_date_and_state.csv")
